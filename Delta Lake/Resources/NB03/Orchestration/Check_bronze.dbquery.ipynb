-- %%
SELECT 
  'Table crime_stats_bronze exists and has data' AS table_status
FROM crime_stats_bronze
LIMIT 1;

SELECT 
  'Table commune_bronze exists and has data' AS table_status
FROM commune_bronze
LIMIT 1;

SELECT 
  'Table departement_bronze exists and has data' AS table_status
FROM departement_bronze
LIMIT 1;

SELECT 
  'Table region_bronze exists and has data' AS table_status
FROM region_bronze
LIMIT 1;
