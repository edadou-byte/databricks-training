-- %%
SELECT 
  'Table communes_enrichies_silver exists and has data' AS table_status
FROM communes_enrichies_silver
LIMIT 1;

SELECT 
  'Table crime_stats_silver exists and has data' AS table_status
FROM crime_stats_silver
LIMIT 1;
