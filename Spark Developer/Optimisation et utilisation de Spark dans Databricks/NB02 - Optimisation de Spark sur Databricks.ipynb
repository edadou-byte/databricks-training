# %% [markdown]
# à faire quand env azure sera fait
#
# https://customer-academy.databricks.com/learn/learning-plans/160/apache-spark-developer-learning-plan/courses/3993/monitoring-and-optimizing-apache-spark-workloads-on-databricks/lessons/37002/demo-optimizing-apache-spark
#
#
# la démo optimizaing apache spark
