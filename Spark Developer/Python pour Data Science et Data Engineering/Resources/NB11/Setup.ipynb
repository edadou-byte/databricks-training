# %% [markdown]
# ### Setup pour Notebook NB11
# Ce notebook :
# - Récupérer la valeur du widget full_path (du notebook parent NB11) et créer un dataframe Pandas à partir du fichier CSV

# %%
print(f"création du dataframe à partir du fichier {full_path_value}")
full_path_value = dbutils.widgets.get("full_path")

df = pd.read_csv(full_path_value)
